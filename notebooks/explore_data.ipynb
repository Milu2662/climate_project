# %%
# !pip3 install pandas pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
# ...
#   Using cached pyarrow-21.0.0-cp39-cp39-macosx_12_0_arm64.whl (31.2 MB)
# ...
#   Using cached pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# ...
#   WARNING: The scripts f2py and numpy-config are installed in '/Users/milu/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_parquet("../datalake_silver/data.parquet")
df.head()
# Out:
#                                                 text  sentiment_score  \
# 0  ‘It was our little idyll – until the solar far...          -0.4497
# 1  Revealed: the world’s worst mega-leaks of meth...          -0.9645
# 2  ‘Smokeless’ fuels produce more ultrafine parti...           0.2382
# 3  Reduced physical activity due to global heatin...          -0.7650
# 4  ‘Hybrid organ’: how a union of trees and fungi...           0.8885
#
#       label
# 0  negative
# 1  negative
# 2  positive
# 3  negative
# 4  positive

# %%
df["label"].value_counts()
# Out:
# label
# negative    165
# positive    141
# neutral      48
# Name: count, dtype: int64
